# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow.keras import layers as L


def inverted_residual_block(inputs, num_filters, strides=1, expansion_ratio=1):
    ## Point-Wise Convolution
    x = L.Conv2D(
        filters=expansion_ratio*inputs.shape[-1],
        kernel_size=1,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Depth-Wise Convolution
    x = L.DepthwiseConv2D(
        kernel_size=3,
        strides=strides,
        padding="same",
        use_bias=False
    )(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Point-Wise Convolution
    x = L.Conv2D(
        filters=num_filters,
        kernel_size=1,
        padding="same",
        use_bias=False
    )(x)
    x = L.BatchNormalization()(x)

    ## Residual Connection
    if strides == 1 and (inputs.shape == x.shape):
        return L.Add()([inputs, x])
    return x


def mlp(x, mlp_dim, dim, dropout_rate=0.1):
    x = L.Dense(mlp_dim, activation="swish")(x)
    x = L.Dropout(dropout_rate)(x)
    x = L.Dense(dim)(x)
    x = L.Dropout(dropout_rate)(x)
    return x

def transformer_encoder(x, num_heads, dim, mlp_dim):
    skip_1 = x
    x = L.LayerNormalization()(x)
    x = L.MultiHeadAttention(
        num_heads=num_heads, key_dim=dim
    )(x, x)
    x = L.Add()([x, skip_1])

    skip_2 = x
    x = L.LayerNormalization()(x)
    x = mlp(x, mlp_dim, dim)
    x = L.Add()([x, skip_2])

    return x

def mobile_vit_block(inputs, num_filters, dim, patch_size=2, num_layers=1):
    B, H, W, C = inputs.shape

    ## 3x3 conv
    x = L.Conv2D(
        filters=C,
        kernel_size=3,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## 1x1 conv: d-dimension
    x = L.Conv2D(
        filters=dim,
        kernel_size=1,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Reshape x to flattened patches
    P = patch_size*patch_size
    N = int(H*W//P)
    x = L.Reshape((P, N, dim))(x)

    ## Transformr Encoder
    for _ in range(num_layers):
        x = transformer_encoder(x, 1, dim, dim*2)

    ## Reshape
    x = L.Reshape((H, W, dim))(x)

    ## 1x1 conv: C-dimension
    x = L.Conv2D(
        filters=C,
        kernel_size=1,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Concatenation
    x = L.Concatenate()([x, inputs])

    ## 3x3 conv
    x = L.Conv2D(
        filters=num_filters,
        kernel_size=3,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    return x

def MobileViT(input_shape, num_channels, dim, expansion_ratio, num_layers=[2, 4, 3], num_classes=1000):
    ## Input layer
    inputs = L.Input(input_shape)

    ## Stem
    x = L.Conv2D(
        filters=num_channels[0],
        kernel_size=3,
        strides=2,
        padding="same",
        use_bias=False
    )(inputs)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)
    x = inverted_residual_block(x, num_channels[1], strides=1, expansion_ratio=expansion_ratio)

    ## Stage 1
    x = inverted_residual_block(x, num_channels[2], strides=2, expansion_ratio=expansion_ratio)
    x = inverted_residual_block(x, num_channels[3], strides=1, expansion_ratio=expansion_ratio)
    x = inverted_residual_block(x, num_channels[4], strides=1, expansion_ratio=expansion_ratio)

    ## Stage 2
    x = inverted_residual_block(x, num_channels[5], strides=2, expansion_ratio=expansion_ratio)
    x = mobile_vit_block(x, num_channels[6], dim[0], num_layers=num_layers[0])

    ## Stage 3
    x = inverted_residual_block(x, num_channels[7], strides=2, expansion_ratio=expansion_ratio)
    x = mobile_vit_block(x, num_channels[8], dim[1], num_layers=num_layers[1])

    ## Stage 4
    x = inverted_residual_block(x, num_channels[9], strides=2, expansion_ratio=expansion_ratio)
    x = mobile_vit_block(x, num_channels[10], dim[2], num_layers=num_layers[2])
    x = L.Conv2D(
        filters=num_channels[11],
        kernel_size=1,
        padding="same",
        use_bias=False
    )(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("swish")(x)

    ## Classifier
    x = L.GlobalAveragePooling2D()(x)
    outputs = L.Dense(num_classes, activation="softmax")(x)

    model = tf.keras.models.Model(inputs, outputs)
    return model


def MobileViT_S(input_shape, num_classes):
    num_channels = [16, 32, 64, 64, 64, 96, 144, 128, 192, 160, 240, 640]
    dim = [144, 192, 240]
    expansion_ratio = 4

    return MobileViT(
        input_shape,
        num_channels,
        dim,
        expansion_ratio,
        num_classes=num_classes
    )

def MobileViT_XS(input_shape, num_classes):
    num_channels = [16, 32, 48, 48, 48, 64, 96, 80, 120, 96, 144, 384]
    dim = [96, 120, 144]
    expansion_ratio = 4

    return MobileViT(
        input_shape,
        num_channels,
        dim,
        expansion_ratio,
        num_classes=num_classes
    )

def MobileViT_XXS(input_shape, num_classes):
    num_channels = [16, 16, 24, 24, 24, 48, 64, 64, 80, 80, 96, 320]
    dim = [64, 80, 96]
    expansion_ratio = 2

    return MobileViT(
        input_shape,
        num_channels,
        dim,
        expansion_ratio,
        num_classes=num_classes
    )


if __name__ == "__main__":


    model = MobileViT_XXS((256, 256, 3), 1000)
    model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)       ┃ Output Shape    ┃   Param # ┃ Connected to     ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ input_layer        │ (None, 256,     │         0 │ -                │
# │ (InputLayer)       │ 256, 3)         │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d (Conv2D)    │ (None, 128,     │       432 │ input_layer[0][… │
# │                    │ 128, 16)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 128,     │        64 │ conv2d[0][0]     │
# │ (BatchNormalizati… │ 128, 16)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation         │ (None, 128,     │         0 │ batch_normaliza… │
# │ (Activation)       │ 128, 16)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_1 (Conv2D)  │ (None, 128,     │       512 │ activation[0][0] │
# │                    │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 128,     │       128 │ conv2d_1[0][0]   │
# │ (BatchNormalizati… │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_1       │ (None, 128,     │         0 │ batch_normaliza… │
# │ (Activation)       │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d   │ (None, 128,     │       288 │ activation_1[0]… │
# │ (DepthwiseConv2D)  │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 128,     │       128 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_2       │ (None, 128,     │         0 │ batch_normaliza… │
# │ (Activation)       │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_2 (Conv2D)  │ (None, 128,     │       512 │ activation_2[0]… │
# │                    │ 128, 16)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 128,     │        64 │ conv2d_2[0][0]   │
# │ (BatchNormalizati… │ 128, 16)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ add (Add)          │ (None, 128,     │         0 │ activation[0][0… │
# │                    │ 128, 16)        │           │ batch_normaliza… │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_3 (Conv2D)  │ (None, 128,     │       512 │ add[0][0]        │
# │                    │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 128,     │       128 │ conv2d_3[0][0]   │
# │ (BatchNormalizati… │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_3       │ (None, 128,     │         0 │ batch_normaliza… │
# │ (Activation)       │ 128, 32)        │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d_1 │ (None, 64, 64,  │       288 │ activation_3[0]… │
# │ (DepthwiseConv2D)  │ 32)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │       128 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 32)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_4       │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 32)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_4 (Conv2D)  │ (None, 64, 64,  │       768 │ activation_4[0]… │
# │                    │ 24)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │        96 │ conv2d_4[0][0]   │
# │ (BatchNormalizati… │ 24)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_5 (Conv2D)  │ (None, 64, 64,  │     1,152 │ batch_normaliza… │
# │                    │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │       192 │ conv2d_5[0][0]   │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_5       │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d_2 │ (None, 64, 64,  │       432 │ activation_5[0]… │
# │ (DepthwiseConv2D)  │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │       192 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_6       │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_6 (Conv2D)  │ (None, 64, 64,  │     1,152 │ activation_6[0]… │
# │                    │ 24)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │        96 │ conv2d_6[0][0]   │
# │ (BatchNormalizati… │ 24)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ add_1 (Add)        │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │                    │ 24)             │           │ batch_normaliza… │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_7 (Conv2D)  │ (None, 64, 64,  │     1,152 │ add_1[0][0]      │
# │                    │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │       192 │ conv2d_7[0][0]   │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_7       │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d_3 │ (None, 64, 64,  │       432 │ activation_7[0]… │
# │ (DepthwiseConv2D)  │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │       192 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_8       │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_8 (Conv2D)  │ (None, 64, 64,  │     1,152 │ activation_8[0]… │
# │                    │ 24)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │        96 │ conv2d_8[0][0]   │
# │ (BatchNormalizati… │ 24)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ add_2 (Add)        │ (None, 64, 64,  │         0 │ add_1[0][0],     │
# │                    │ 24)             │           │ batch_normaliza… │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_9 (Conv2D)  │ (None, 64, 64,  │     1,152 │ add_2[0][0]      │
# │                    │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 64, 64,  │       192 │ conv2d_9[0][0]   │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_9       │ (None, 64, 64,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d_4 │ (None, 32, 32,  │       432 │ activation_9[0]… │
# │ (DepthwiseConv2D)  │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 32, 32,  │       192 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_10      │ (None, 32, 32,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_10 (Conv2D) │ (None, 32, 32,  │     2,304 │ activation_10[0… │
# │                    │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 32, 32,  │       192 │ conv2d_10[0][0]  │
# │ (BatchNormalizati… │ 48)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_14 (Conv2D) │ (None, 32, 32,  │    27,648 │ batch_normaliza… │
# │                    │ 64)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 32, 32,  │       256 │ conv2d_14[0][0]  │
# │ (BatchNormalizati… │ 64)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_14      │ (None, 32, 32,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 64)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_15 (Conv2D) │ (None, 32, 32,  │     8,192 │ activation_14[0… │
# │                    │ 128)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 32, 32,  │       512 │ conv2d_15[0][0]  │
# │ (BatchNormalizati… │ 128)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_15      │ (None, 32, 32,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 128)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d_5 │ (None, 16, 16,  │     1,152 │ activation_15[0… │
# │ (DepthwiseConv2D)  │ 128)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 16, 16,  │       512 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 128)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_16      │ (None, 16, 16,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 128)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_16 (Conv2D) │ (None, 16, 16,  │     8,192 │ activation_16[0… │
# │                    │ 64)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 16, 16,  │       256 │ conv2d_16[0][0]  │
# │ (BatchNormalizati… │ 64)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_20 (Conv2D) │ (None, 16, 16,  │    46,080 │ batch_normaliza… │
# │                    │ 80)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 16, 16,  │       320 │ conv2d_20[0][0]  │
# │ (BatchNormalizati… │ 80)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_20      │ (None, 16, 16,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 80)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_21 (Conv2D) │ (None, 16, 16,  │    12,800 │ activation_20[0… │
# │                    │ 160)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 16, 16,  │       640 │ conv2d_21[0][0]  │
# │ (BatchNormalizati… │ 160)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_21      │ (None, 16, 16,  │         0 │ batch_normaliza… │
# │ (Activation)       │ 160)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ depthwise_conv2d_6 │ (None, 8, 8,    │     1,440 │ activation_21[0… │
# │ (DepthwiseConv2D)  │ 160)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 8, 8,    │       640 │ depthwise_conv2… │
# │ (BatchNormalizati… │ 160)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_22      │ (None, 8, 8,    │         0 │ batch_normaliza… │
# │ (Activation)       │ 160)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_22 (Conv2D) │ (None, 8, 8,    │    12,800 │ activation_22[0… │
# │                    │ 80)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 8, 8,    │       320 │ conv2d_22[0][0]  │
# │ (BatchNormalizati… │ 80)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_26 (Conv2D) │ (None, 8, 8,    │    69,120 │ batch_normaliza… │
# │                    │ 96)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 8, 8,    │       384 │ conv2d_26[0][0]  │
# │ (BatchNormalizati… │ 96)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_26      │ (None, 8, 8,    │         0 │ batch_normaliza… │
# │ (Activation)       │ 96)             │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ conv2d_27 (Conv2D) │ (None, 8, 8,    │    30,720 │ activation_26[0… │
# │                    │ 320)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ batch_normalizati… │ (None, 8, 8,    │     1,280 │ conv2d_27[0][0]  │
# │ (BatchNormalizati… │ 320)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ activation_27      │ (None, 8, 8,    │         0 │ batch_normaliza… │
# │ (Activation)       │ 320)            │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ global_average_po… │ (None, 320)     │         0 │ activation_27[0… │
# │ (GlobalAveragePoo… │                 │           │                  │
# ├────────────────────┼─────────────────┼───────────┼──────────────────┤
# │ dense_18 (Dense)   │ (None, 1000)    │   321,000 │ global_average_… │
# └────────────────────┴─────────────────┴───────────┴──────────────────┘
#  Total params: 559,208 (2.13 MB)
#  Trainable params: 555,512 (2.12 MB)
#  Non-trainable params: 3,696 (14.44 KB)
